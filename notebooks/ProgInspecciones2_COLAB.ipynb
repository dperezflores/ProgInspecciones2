# %% [markdown]
# # ProgInspecciones2 — Ejecución
#
# Este es el notebook operativo del proyecto.
#
# **Uso normal:** ejecuta únicamente la celda siguiente. Ella monta Google Drive, clona o actualiza GitHub, instala dependencias y ejecuta la versión más reciente del proyecto.

# %%
from google.colab import drive
import os

# 1) Montar Google Drive
drive.mount('/content/drive', force_remount=False)

# 2) Clonar o actualizar el repositorio
REPO_DIR = '/content/ProgInspecciones2'
REPO_URL = 'https://github.com/dperezflores/ProgInspecciones2.git'

if os.path.exists(os.path.join(REPO_DIR, '.git')):
    # %cd /content/ProgInspecciones2
    # !git pull --ff-only
else:
    # %cd /content
    # !git clone $REPO_URL
    # %cd /content/ProgInspecciones2

# 3) Instalar/actualizar dependencias
# !pip -q install -r requirements.txt

# 4) Ejecutar el pipeline en un proceso Python nuevo.
# Esto evita que Colab reutilice módulos antiguos que quedaron en memoria.
# !python /content/ProgInspecciones2/run_pipeline.py
