# %% [markdown]
# # ProgInspecciones2 — Fase 0
#
# Prueba de conexión entre Google Colab, Google Drive y el repositorio GitHub.
#
# Este notebook no ejecuta todavía ningún optimizador.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

REPO_DIR = '/content/ProgInspecciones2'
REPO_URL = 'https://github.com/dperezflores/ProgInspecciones2.git'

if os.path.exists(REPO_DIR):
    # %cd /content/ProgInspecciones2
    # !git pull
else:
    # %cd /content
    # !git clone $REPO_URL
    # %cd /content/ProgInspecciones2

# %%
# !pip -q install -r requirements.txt

# %%
from src.paths import SOURCE_EXCEL_PATH
from src.config import SOURCE_SHEET
from src.carga_datos import listar_hojas, cargar_hoja, resumen_dataframe
from src.validacion import validar_dataframe_no_vacio

print('Ruta del archivo:')
print(SOURCE_EXCEL_PATH)

hojas = listar_hojas(SOURCE_EXCEL_PATH)
print('\nHojas disponibles:')
for hoja in hojas:
    print(' -', hoja)

# %%
df = cargar_hoja(SOURCE_EXCEL_PATH, SOURCE_SHEET)
validar_dataframe_no_vacio(df)

resumen = resumen_dataframe(df)
print('Resumen de carga:')
for clave, valor in resumen.items():
    if clave != 'nombres_columnas':
        print(f'{clave}: {valor}')

display(df.head(10))

# %% [markdown]
# ## Resultado esperado
#
# Si todas las celdas anteriores terminan sin error y se muestra la tabla del Excel, la Fase 0 de conexión queda validada.

# %% [markdown]
# ## Fase 1 — Normalización y diagnóstico
#
# A partir de aquí se genera una copia normalizada de los datos. El Excel original no se modifica.

# %%
from src.normalizacion import normalizar_datos, diagnosticar_datos, tabla_calidad

df_norm = normalizar_datos(df)
diagnostico = diagnosticar_datos(df_norm)

print('DIAGNÓSTICO GENERAL')
print('-' * 50)
for clave, valor in diagnostico.items():
    if clave not in {'tipos_inspeccion', 'auditores'}:
        print(f'{clave}: {valor}')

print('\nTipos de inspección:')
for tipo, cantidad in diagnostico['tipos_inspeccion'].items():
    print(f'  {tipo}: {cantidad}')

print('\nAuditores:')
for auditor, cantidad in diagnostico['auditores'].items():
    print(f'  {auditor}: {cantidad}')

# %%
print('CALIDAD DE DATOS POR COLUMNA')
display(tabla_calidad(df_norm))

# %%
print('DATOS NORMALIZADOS — PRIMEROS 10 REGISTROS')
display(df_norm.head(10))

# %% [markdown]
# ### Criterio de cierre de la Fase 1
#
# La fase queda validada cuando el diagnóstico se genera sin errores y los datos normalizados conservan los registros del archivo fuente con nombres de columnas y tipos consistentes.
